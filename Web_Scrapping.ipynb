# %% [markdown]
# <a href="https://colab.research.google.com/github/kiplimopatrick/Web-Scrapping/blob/main/Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Web Scrapping**
#
# In the current technological world the internet is full of data which have different uses. Collecting this data involves a process called web scrapping.
# Web scrapping is thereby a process of extracting and collecting data from websites and storing it on a local machine or a desired database.
# In this process we will use beautifulsoup and requests package to do the process of scrapping a website.
#
# First we will install the required packages:

# %%
# !pip install requests
# !pip install beautifulsoup4

# %%
#Importing the requests and BeautifulSoup module
import requests
from bs4 import BeautifulSoup

# %%
#Declaring a url variable for the website we are  going to scrape.
import requests
from bs4 import BeautifulSoup
url = 'http://www.bu.edu/president/boston-university-facts-stats/'

#We the use the requests get method to fetch the data from the url
response = requests.get(url)
#checking the status
status = response.status_code
print(status) # 200 means the fetching was successful
# Out:
# 200

# %%
#Using beautifulSoup to parse content from the page
#To parse means extracting information from the HTML source and formatting it for further use.
import requests
from bs4 import BeautifulSoup
url = 'http://www.bu.edu/president/boston-university-facts-stats/'
#getting all the contents from the website
content = response.content
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>     <html class="no-js ie lt-ie9 lt-ie8 lt-ie7"  lang="en"> <![endif]-->
# <!--[if IE 7]>        <html class="no-js ie lt-ie9 lt-ie8"  lang="en"> <![endif]-->
# <!--[if IE 8]>        <html class="no-js ie lt-ie9"  lang="en"> <![endif]-->
# <!--[if IE 9]>        <html class="no-js ie ie9"  lang="en"> <![endif]-->
# <!--[if gt IE 9]><!--><html class="no-js" lang="en"><!--<![endif]-->
# <head>
# <title>BU Facts &amp; Stats | Office of the President</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:[]}};(window.NREUM||(NREUM={})).loader_config={xpid:"UgUAV1RQGwQCVVNXAwY=",licenseKey:"b19c58809e",applicationID:"7212547"};;/*! For license information please see nr-loader-full-1.268.0.min.js.LICENSE.txt */
# ...
